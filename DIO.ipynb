# %%
import pandas as pd

# %%
compras_df = pd.read_excel("compras.xlsx")
display(compras_df)
# Out:
#        Código Venda       Data              ID Loja            Produto  \
# 0                 1 2019-01-01   Iguatemi Esplanada     Sapato Estampa
# 1                 1 2019-01-01   Iguatemi Esplanada           Camiseta
# 2                 1 2019-01-01   Iguatemi Esplanada      Sapato Xadrez
# 3                 2 2019-01-02       Norte Shopping            Relógio
# 4                 2 2019-01-02       Norte Shopping       Chinelo Liso
# ...             ...        ...                  ...                ...
# 93905         65012 2019-11-30  Shopping Vila Velha     Mochila Xadrez
# 93906         65013 2019-11-30    Ribeirão Shopping  Pulseira Listrado
# 93907         65013 2019-11-30    Ribeirão Shopping     Cueca Listrado
# 93908         65014 2019-11-30  Shopping Guararapes     Pulseira Linho
# 93909         65014 2019-11-30  Shopping Guararapes      Casaco Xadrez
#
#        Quantidade  Valor Unitário  Valor Final
# 0               1             358          358
# ...

# %%
display(compras_df.head(15))
# Out:
#     Código Venda       Data                           ID Loja  \
# 0              1 2019-01-01                Iguatemi Esplanada
# 1              1 2019-01-01                Iguatemi Esplanada
# 2              1 2019-01-01                Iguatemi Esplanada
# 3              2 2019-01-02                    Norte Shopping
# 4              2 2019-01-02                    Norte Shopping
# 5              3 2019-01-02        Rio Mar Shopping Fortaleza
# 6              5 2019-01-02                    Shopping Barra
# 7              6 2019-01-02               Shopping Ibirapuera
# 8              7 2019-01-02                    Norte Shopping
# 9              7 2019-01-02                    Norte Shopping
# 10             8 2019-01-02                 Iguatemi Campinas
# 11             9 2019-01-02  Shopping Center Leste Aricanduva
# 12             9 2019-01-02  Shopping Center Leste Aricanduva
# 13            10 2019-01-02         Passei das Águas Shopping
# ...

# %%
display(compras_df.head(15))
print(compras_df.shape)
# Out:
#     Código Venda       Data                           ID Loja  \
# 0              1 2019-01-01                Iguatemi Esplanada
# 1              1 2019-01-01                Iguatemi Esplanada
# 2              1 2019-01-01                Iguatemi Esplanada
# 3              2 2019-01-02                    Norte Shopping
# 4              2 2019-01-02                    Norte Shopping
# 5              3 2019-01-02        Rio Mar Shopping Fortaleza
# 6              5 2019-01-02                    Shopping Barra
# 7              6 2019-01-02               Shopping Ibirapuera
# 8              7 2019-01-02                    Norte Shopping
# 9              7 2019-01-02                    Norte Shopping
# 10             8 2019-01-02                 Iguatemi Campinas
# 11             9 2019-01-02  Shopping Center Leste Aricanduva
# 12             9 2019-01-02  Shopping Center Leste Aricanduva
# 13            10 2019-01-02         Passei das Águas Shopping
# ...

# %%
produtos = compras_df[['Produto','ID Loja']]
display(produtos)
# Out:
#                  Produto              ID Loja
# 0         Sapato Estampa   Iguatemi Esplanada
# 1               Camiseta   Iguatemi Esplanada
# 2          Sapato Xadrez   Iguatemi Esplanada
# 3                Relógio       Norte Shopping
# 4           Chinelo Liso       Norte Shopping
# ...                  ...                  ...
# 93905     Mochila Xadrez  Shopping Vila Velha
# 93906  Pulseira Listrado    Ribeirão Shopping
# 93907     Cueca Listrado    Ribeirão Shopping
# 93908     Pulseira Linho  Shopping Guararapes
# 93909      Casaco Xadrez  Shopping Guararapes
#
# [93910 rows x 2 columns]

# %%
# pegar uma linha 
display(compras_df.loc[1:15])
# Out:
#     Código Venda       Data                           ID Loja  \
# 1              1 2019-01-01                Iguatemi Esplanada
# 2              1 2019-01-01                Iguatemi Esplanada
# 3              2 2019-01-02                    Norte Shopping
# 4              2 2019-01-02                    Norte Shopping
# 5              3 2019-01-02        Rio Mar Shopping Fortaleza
# 6              5 2019-01-02                    Shopping Barra
# 7              6 2019-01-02               Shopping Ibirapuera
# 8              7 2019-01-02                    Norte Shopping
# 9              7 2019-01-02                    Norte Shopping
# 10             8 2019-01-02                 Iguatemi Campinas
# 11             9 2019-01-02  Shopping Center Leste Aricanduva
# 12             9 2019-01-02  Shopping Center Leste Aricanduva
# 13            10 2019-01-02         Passei das Águas Shopping
# 14            10 2019-01-02         Passei das Águas Shopping
# ...

# %%
# pegar uma linha ou coluna em uma condição especifica
# condição [linha,coluna]
print(compras_df.loc[10,'Produto'])
# Out:
# Terno Estampa

# %%
# pegar varias linhas e colunas usando o loc
compras_shopp_recife = compras_df.loc[compras_df['ID Loja'] == 'Shopping Recife',["ID Loja","Produto","Quantidade"]]
display(compras_shopp_recife)
# Out:
#                ID Loja         Produto  Quantidade
# 15     Shopping Recife        Camiseta           1
# 16     Shopping Recife  Calça Listrado           9
# 17     Shopping Recife  Camisa Estampa           1
# 61     Shopping Recife    Camisa Linho           1
# 122    Shopping Recife     Meia Xadrez           1
# ...                ...             ...         ...
# 93684  Shopping Recife  Camiseta Linho           1
# 93696  Shopping Recife     Terno Linho           2
# 93697  Shopping Recife           Terno           4
# 93698  Shopping Recife   Bermuda Linho           5
# 93765  Shopping Recife   Bermuda Linho           1
#
# [3605 rows x 3 columns]
